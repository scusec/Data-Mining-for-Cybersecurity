# %% [markdown]
# ## 导入数据

# %%
import sklearn.feature_extraction
import pandas as pd
import os
import csv
import numpy as np

# %% [markdown]
# 这里只有一个正常sql的文件名为legit，剩余文件数据为sqli语句，正常的标0，其余标1

# %%
basedir = 'data'
filelist = os.listdir(basedir) 
df_list = []
for file in filelist:
    #osos.path.join(basedir,file)的作用是将参数转化成“basedir/file”的路径
    df = pd.read_csv(os.path.join(basedir,file), quoting=csv.QUOTE_NONE, names=['raw_sql'], header=None)
    df['label'] = 0 if file.split('.')[0] == 'legit' else 1
    df_list.append(df)
dataframe = pd.concat(df_list, ignore_index=True)
dataframe.dropna(inplace=True)
print (dataframe['label'].value_counts())
dataframe.head()
# Out:
# 1    12672
# 0     1003
# Name: label, dtype: int64
#             raw_sql  label
# 0       ) AND 93=93      1
# 1   ) AND 9170=2793      1
# 2  ') AND 7364=5114      1
# 3      ') AND 93=93      1
# 4   ') AND 4731=891      1

# %% [markdown]
# 把sql标记化

# %%
import sqlparse
def parse_it(raw_sql):
    parsed = sqlparse.parse(str(raw_sql))
    return [token._get_repr_name() for parse in parsed for token in parse.tokens if token._get_repr_name() != 'Whitespace']

dataframe['parsed_sql'] = dataframe['raw_sql'].map(lambda x: parse_it(x))

# %%
dataframe.head()
# Out:
#                                         raw_sql  label  \
# 0                                   ) AND 93=93      1
# 1                               ) AND 9170=2793      1
# 2                              ') AND 7364=5114      1
# 3                                  ') AND 93=93      1
# 4                               ') AND 4731=891      1
# 5                               ' AND 5874=2869      1
# 6                                   ' AND 93=93      1
# 7                                ' AND 529=7832      1
# 8                               " AND 5183=1335      1
# 9                                   " AND 93=93      1
# 10                              " AND 5984=4419      1
# 11               ) AND 8703=8428 AND (7243=7243      1
# 12                   ) AND 93=93 AND (5302=5302      1
# 13               ) AND 8117=9417 AND (1286=1286      1
# 14             )) AND 3196=7637 AND ((6424=6424      1
# 15                 )) AND 93=93 AND ((1849=1849      1
# 16               )) AND 4113=33 AND ((6244=6244      1
# 17           ))) AND 7371=4214 AND (((6219=6219      1
# 18               ))) AND 93=93 AND (((2816=2816      1
# 19           ))) AND 9563=2025 AND (((4031=4031      1
# 20                                AND 5642=4589      1
# 21                                    AND 93=93      1
# 22                                 AND 431=3779      1
# 23           ') AND 9503=9264 AND ('bRfS'='bRfS      1
# 24               ') AND 93=93 AND ('ZIYy'='ZIYy      1
# 25           ') AND 8638=8712 AND ('twvD'='twvD      1
# 26         ')) AND 2746=5177 AND (('vIva'='vIva      1
# 27             ')) AND 93=93 AND (('dunz'='dunz      1
# 28         ')) AND 1340=9153 AND (('sXcm'='sXcm      1
# 29       '))) AND 7025=7439 AND ((('wzOL'='wzOL      1
# 30           '))) AND 93=93 AND ((('oMMM'='oMMM      1
# 31       '))) AND 9421=9484 AND ((('ZaIT'='ZaIT      1
# 32             ' AND 2218=4751 AND 'ixQM'='ixQM      1
# 33                 ' AND 93=93 AND 'bleu'='bleu      1
# 34             ' AND 6445=6310 AND 'ECOC'='ECOC      1
# 35      ') AND 5219=9633 AND ('mlgR' LIKE 'mlgR      1
# 36          ') AND 93=93 AND ('KDlb' LIKE 'KDlb      1
# 37      ') AND 7066=1108 AND ('DIva' LIKE 'DIva      1
# 38    ')) AND 5824=3983 AND (('dGjV' LIKE 'dGjV      1
# 39        ')) AND 93=93 AND (('eOHm' LIKE 'eOHm      1
# 40    ')) AND 9066=5960 AND (('TKKi' LIKE 'TKKi      1
# 41  '))) AND 7586=6671 AND ((('IJbl' LIKE 'IJbl      1
# 42      '))) AND 93=93 AND ((('UFCU' LIKE 'UFCU      1
# 43   '))) AND 6476=115 AND ((('tCfT' LIKE 'tCfT      1
# 44        ' AND 2116=1625 AND 'DyoS' LIKE 'DyoS      1
# 45            ' AND 93=93 AND 'IJBj' LIKE 'IJBj      1
# 46        ' AND 1517=8497 AND 'lpul' LIKE 'lpul      1
# 47           ") AND 2936=9230 AND ("rDPV"="rDPV      1
# 48               ") AND 93=93 AND ("pZoR"="pZoR      1
# 49           ") AND 1933=3702 AND ("jwwH"="jwwH      1
#
#                                            parsed_sql
# 0                  [Punctuation, Keyword, Comparison]
# 1                  [Punctuation, Keyword, Comparison]
# 2           [Error, Punctuation, Keyword, Comparison]
# 3           [Error, Punctuation, Keyword, Comparison]
# 4           [Error, Punctuation, Keyword, Comparison]
# 5                        [Error, Keyword, Comparison]
# 6                        [Error, Keyword, Comparison]
# 7                        [Error, Keyword, Comparison]
# 8                        [Error, Keyword, Comparison]
# 9                        [Error, Keyword, Comparison]
# 10                       [Error, Keyword, Comparison]
# 11  [Punctuation, Keyword, Comparison, Keyword, Pu...
# 12  [Punctuation, Keyword, Comparison, Keyword, Pu...
# 13  [Punctuation, Keyword, Comparison, Keyword, Pu...
# 14  [Punctuation, Punctuation, Keyword, Comparison...
# 15  [Punctuation, Punctuation, Keyword, Comparison...
# 16  [Punctuation, Punctuation, Keyword, Comparison...
# 17  [Punctuation, Punctuation, Punctuation, Keywor...
# 18  [Punctuation, Punctuation, Punctuation, Keywor...
# 19  [Punctuation, Punctuation, Punctuation, Keywor...
# 20                              [Keyword, Comparison]
# 21                              [Keyword, Comparison]
# 22                              [Keyword, Comparison]
# 23           [Single, Identifier, Single, Identifier]
# 24           [Single, Identifier, Single, Identifier]
# 25           [Single, Identifier, Single, Identifier]
# 26           [Single, Identifier, Single, Identifier]
# 27           [Single, Identifier, Single, Identifier]
# 28           [Single, Identifier, Single, Identifier]
# 29           [Single, Identifier, Single, Identifier]
# 30           [Single, Identifier, Single, Identifier]
# 31           [Single, Identifier, Single, Identifier]
# 32           [Single, Identifier, Single, Identifier]
# 33           [Single, Identifier, Single, Identifier]
# 34           [Single, Identifier, Single, Identifier]
# 35           [Single, Identifier, Single, Identifier]
# 36           [Single, Identifier, Single, Identifier]
# 37           [Single, Identifier, Single, Identifier]
# 38           [Single, Identifier, Single, Identifier]
# 39           [Single, Identifier, Single, Identifier]
# 40           [Single, Identifier, Single, Identifier]
# 41           [Single, Identifier, Single, Identifier]
# 42           [Single, Identifier, Single, Identifier]
# 43           [Single, Identifier, Single, Identifier]
# 44           [Single, Identifier, Single, Identifier]
# 45           [Single, Identifier, Single, Identifier]
# 46           [Single, Identifier, Single, Identifier]
# 47                           [Identifier, Identifier]
# 48                           [Identifier, Identifier]
# 49                           [Identifier, Identifier]

# %% [markdown]
# 使用ngram来展现各标记之间的联系

# %%
def ngrams(lst):
    N = 3
    ngrams = []
    for n in range(0,N):
        # *表示转置
        ngrams += zip(*(lst[i:] for i in range(n+1)))
    return [str(tuple) for tuple in ngrams]

# %%
matrix = dataframe.as_matrix()
X = matrix[:, 0]
Y = matrix[:, 1]
#改变label的数据类型，便于后面的预测
Y = np.array(Y, dtype=np.int)
# Out:
# /Users/dqy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score

# %% [markdown]
# 数据向量化

# %%
vectorizer = TfidfVectorizer(tokenizer=ngrams)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %% [markdown]
# ## 训练数据

# %%
clf = RandomForestClassifier()
#一般训练数据使用fit_transform来转换
X_train = vectorizer.fit_transform(X_train)
clf.fit(X_train, y_train)
X_test = vectorizer.transform(X_test)
y_probs= clf.predict_proba(X_test)[:,1]
# Out:
# /Users/dqy/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# ## 打印准确率和召回率

# %%
print("accuracy:%f"%(sklearn.metrics.accuracy_score(y_test, y_probs>.9)))
print("recall:%f"%(sklearn.metrics.recall_score(y_test, y_probs>=.9)))
# Out:
# accuracy:0.991959
# recall:0.995290

# %% [markdown]
# ## 测试

# %%
def test_it(sql):
    parsed_sql = parse_it(sql)
    _X = vectorizer.transform(parsed_sql)
    my=clf.predict(_X)[0]
    if(my):
        print("%s is a SQL injection statement"%sql)
    else:
        print("%s is benign"%sql)

# %%
test_it('select * from employees')
test_it("'; exec master..xp_cmdshell")
test_it("'any 'x'='x'")
test_it('from dorseys mom xp_cmdshell biache')
test_it('select * from your_mom')
# Out:
# select * from employees is benign
# '; exec master..xp_cmdshell is a SQL injection statement
# 'any 'x'='x' is a SQL injection statement
# from dorseys mom xp_cmdshell biache is a SQL injection statement
# select * from your_mom is benign
