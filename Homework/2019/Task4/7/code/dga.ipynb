# %%
import pandas as pd
import numpy as np
from math import log
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dga_names = ['dga_family', 'domain', 'start_date', 'start_time', 'end_date', 'end_time']
dga = pd.read_csv('dga.txt',header=None, sep='\s+')
dga.columns = dga_names
dga.head()
# Out:
#   dga_family         domain  start_date start_time    end_date  end_time
# 0     nymaim     ooloda.com  2019-10-23   00:00:00  2019-10-23  23:59:59
# 1     nymaim  ovpxymiqg.biz  2019-10-23   00:00:00  2019-10-23  23:59:59
# 2     nymaim  klaidigdl.com  2019-10-23   00:00:00  2019-10-23  23:59:59
# 3     nymaim    moftmgt.com  2019-10-23   00:00:00  2019-10-23  23:59:59
# 4     nymaim   inxpnnpx.biz  2019-10-23   00:00:00  2019-10-23  23:59:59

# %%
normal = pd.read_csv('all_legit.txt', header=None, sep='\s+')
legit_names = ['domain', 'label']
normal.columns = legit_names

# %%
dga = dga.drop('dga_family', axis=1)
dga = dga.drop('start_date', axis=1)
dga = dga.drop('start_time', axis=1)
dga = dga.drop('end_date', axis=1)
dga = dga.drop('end_time', axis=1)
dga['label'] = 1
dga.head()
# Out:
#           domain  label
# 0     ooloda.com      1
# 1  ovpxymiqg.biz      1
# 2  klaidigdl.com      1
# 3    moftmgt.com      1
# 4   inxpnnpx.biz      1

# %%
data = pd.concat([normal, dga], axis=0, ignore_index=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224172 entries, 0 to 2224171
# Data columns (total 2 columns):
# domain    object
# label     int64
# dtypes: int64(1), object(1)
# memory usage: 33.9+ MB

# %%
def get_main_domain(domain):
    domain_list = domain.split('.')
    result = ''
    for i in range(len(domain_list) - 1):
        result = result + domain_list[i] + '.'
    result = result.rstrip('.')
    if result == '':
        return domain
    else:
        return result

data['main_domain'] = data['domain'].map(lambda x: get_main_domain(x))

# %%
data.drop_duplicates('main_domain', inplace=True)
data = data.dropna()

# %%
data.reset_index(drop=True, inplace=True)

# %%
data['len'] = data['main_domain'].map(lambda x: len(x))

# %%
def get_vowel(domain):
    length = len(domain)
    domain = domain.lower()
    result = domain.count('a') + domain.count('e') + domain.count('i') + domain.count('o') + domain.count('u')
    return result / length

# %%
data['vowel'] = data['main_domain'].map(lambda x: get_vowel(x))

# %%
import re
def get_consonants(domain):
    it = re.finditer(r'([bcdfghjklmnpqrstvwxyz])*', domain)
    count = 0
    for node in it:
        #print node.group()
        len_node = len(node.group())
        if len_node > 1:
            count += len_node
    return count

# %%
data['consonants'] = data['main_domain'].map(lambda x: get_consonants(x))

# %%
import math
def get_shannon(x):
    url = x
    tmp_dict = {}
    url_len = len(url)
    for i in range(0,url_len):
        if url[i] in tmp_dict.keys():
            tmp_dict[url[i]] = tmp_dict[url[i]] + 1
        else:
            tmp_dict[url[i]] = 1
    shannon = 0
    for i in tmp_dict.keys():
        p = float(tmp_dict[i]) / url_len
        shannon = shannon - p * math.log(p,2)
    return shannon

data['shannon'] = data['main_domain'].map(lambda x: get_shannon(x))

# %%
def get_num(domain):
    length = len(domain)
    domain = domain.lower()
    result = domain.count('0') + domain.count('1') + domain.count('2') + domain.count('3') + domain.count('4') + domain.count('5') + \
            domain.count('6') + domain.count('7') + domain.count('8') + domain.count('9')
    return result / length

# %%
data['num'] = data['main_domain'].map(lambda x: get_num(x))

# %%
from nltk.collocations import *
import nltk
def get_bigram(domain):
    finder = BigramCollocationFinder.from_words(domain)
    bigram_measures = nltk.collocations.BigramAssocMeasures()
    scored = finder.score_ngrams(bigram_measures.pmi)
    result = 0
    for i in scored:
        result = result + i[1]
    return int(result)

# %%
data['bigram'] = data['main_domain'].map(lambda x: get_bigram(x))

# %%
def get_trigram(domain):
    trigram_measures = nltk.collocations.TrigramAssocMeasures()
    trigram_finder = TrigramCollocationFinder.from_words(domain)
    scored = trigram_finder.score_ngrams(trigram_measures.poisson_stirling)
    result = 0
    for i in scored:
        result = result + i[1]
    return int(result)

# %%
data['trigram'] = data['main_domain'].map(lambda x: get_trigram(x))

# %%
data
# Out:
#                           domain  label          main_domain  len     vowel  \
# 0                     google.com      0               google    6  0.500000
# 1                   facebook.com      0             facebook    8  0.500000
# 2                    youtube.com      0              youtube    7  0.571429
# 3                      baidu.com      0                baidu    5  0.600000
# 4                      yahoo.com      0                yahoo    5  0.600000
# 5                     amazon.com      0               amazon    6  0.500000
# 6                  wikipedia.org      0            wikipedia    9  0.555556
# 7                         qq.com      0                   qq    2  0.000000
# 8                    twitter.com      0              twitter    7  0.285714
# 9                     taobao.com      0               taobao    6  0.666667
# 10                  google.co.in      0            google.co    9  0.444444
# 11                      live.com      0                 live    4  0.500000
# 12                   sina.com.cn      0             sina.com    8  0.375000
# 13                  linkedin.com      0             linkedin    8  0.375000
# 14                   yahoo.co.jp      0             yahoo.co    8  0.500000
# 15                     weibo.com      0                weibo    5  0.600000
# 16                      bing.com      0                 bing    4  0.250000
# 17                      ebay.com      0                 ebay    4  0.500000
# 18                     yandex.ru      0               yandex    6  0.333333
# 19                        vk.com      0                   vk    2  0.000000
# 20                    hao123.com      0               hao123    6  0.333333
# 21                     tmall.com      0                tmall    5  0.200000
# 22                       msn.com      0                  msn    3  0.000000
# 23                 instagram.com      0            instagram    9  0.333333
# 24                  amazon.co.jp      0            amazon.co    9  0.444444
# 25                          t.co      0                    t    1  0.000000
# 26                 pinterest.com      0            pinterest    9  0.333333
# 27                onclickads.net      0           onclickads   10  0.300000
# 28                    reddit.com      0               reddit    6  0.333333
# 29                       mail.ru      0                 mail    4  0.500000
# ...                          ...    ...                  ...  ...       ...
# 2115444           hvigpdbibf.com      1           hvigpdbibf   10  0.200000
# 2115445   oxcssyaaiinqmrrnke.com      1   oxcssyaaiinqmrrnke   18  0.333333
# 2115446        tasggujxevhqk.com      1        tasggujxevhqk   13  0.230769
# 2115447          mptpxdjlsyl.com      1          mptpxdjlsyl   11  0.000000
# 2115448           ntlokoyhty.com      1           ntlokoyhty   10  0.200000
# 2115449      kxsrkiknbiehdna.com      1      kxsrkiknbiehdna   15  0.266667
# 2115450  lvjosduqyvbqvyujocm.com      1  lvjosduqyvbqvyujocm   19  0.210526
# 2115451           knmalwfcsk.com      1           knmalwfcsk   10  0.100000
# 2115452       tkliogftrghuft.com      1       tkliogftrghuft   14  0.214286
# 2115453  twskpkurthqpfbolfds.com      1  twskpkurthqpfbolfds   19  0.105263
# 2115454           yvnoqwxuvg.com      1           yvnoqwxuvg   10  0.200000
# 2115455             sffggjmj.com      1             sffggjmj    8  0.000000
# 2115456             efiohqjg.com      1             efiohqjg    8  0.375000
# 2115457       deacxqwfddcoll.com      1       deacxqwfddcoll   14  0.214286
# 2115458      idpbxlpoksvcydm.com      1      idpbxlpoksvcydm   15  0.133333
# 2115459          egiyjekimbw.com      1          egiyjekimbw   11  0.363636
# 2115460             kdroqhsu.com      1             kdroqhsu    8  0.250000
# 2115461    nteytvdebgiekbypy.com      1    nteytvdebgiekbypy   17  0.235294
# 2115462             pmjynmch.com      1             pmjynmch    8  0.000000
# 2115463             pqfkyhdi.com      1             pqfkyhdi    8  0.125000
# 2115464             gbbcuwoa.com      1             gbbcuwoa    8  0.375000
# 2115465             danikbyt.com      1             danikbyt    8  0.250000
# 2115466  lmaylpvldchmpurcsho.com      1  lmaylpvldchmpurcsho   19  0.157895
# 2115467       cfsslmudgpvcqj.com      1       cfsslmudgpvcqj   14  0.071429
# 2115468     iuyiprquvwcejhrr.com      1     iuyiprquvwcejhrr   16  0.312500
# 2115469          psiikeubalj.com      1          psiikeubalj   11  0.454545
# 2115470    sdkyqsobwowrgorpg.com      1    sdkyqsobwowrgorpg   17  0.176471
# 2115471    pixqvtywsduaokrst.com      1    pixqvtywsduaokrst   17  0.235294
# 2115472        htmhndgsskqjd.com      1        htmhndgsskqjd   13  0.000000
# 2115473       aogjqrkoevglat.com      1       aogjqrkoevglat   14  0.357143
#
#          consonants   shannon  num  bigram  trigram
# 0                 2  1.918296  0.0       5        7
# 1                 0  2.750000  0.0      17       25
# 2                 0  2.521641  0.0      12       17
# 3                 0  2.321928  0.0       9       10
# 4                 0  1.921928  0.0       6        7
# 5                 0  2.251629  0.0       9       12
# 6                 0  2.641604  0.0      15       26
# 7                 2  0.000000  0.0      -1        0
# 8                 4  2.128085  0.0       8       11
# 9                 0  1.918296  0.0       6        8
# 10                2  2.419382  0.0      14       23
# 11                0  2.000000  0.0       6        6
# 12                0  3.000000  0.0      21       30
# 13                2  2.500000  0.0      14       22
# 14                0  2.405639  0.0      13       18
# 15                0  2.321928  0.0       9       10
# 16                2  2.000000  0.0       6        6
# 17                0  2.000000  0.0       6        6
# 18                2  2.584963  0.0      12       16
# 19                2  1.000000  0.0       1        0
# 20                0  2.584963  0.5      12       16
# 21                4  1.921928  0.0       6        7
# 22                3  1.584963  0.0       3        2
# 23                5  2.947703  0.0      21       32
# 24                0  2.725481  0.0      19       29
# 25                0  0.000000  0.0       0        0
# 26                4  2.725481  0.0      18       27
# 27                7  3.121928  0.0      25       39
# 28                2  2.251629  0.0       8       10
# 29                0  2.000000  0.0       6        6
# ...             ...       ...  ...     ...      ...
# 2115444           8  2.921928  0.0      21       34
# 2115445          12  3.614369  0.0      50       87
# 2115446           9  3.546594  0.0      40       64
# 2115447          11  3.095795  0.0      27       44
# 2115448           7  2.721928  0.0      18       31
# 2115449          11  3.323231  0.0      38       66
# 2115450          14  3.471354  0.0      45       84
# 2115451           9  3.121928  0.0      27       43
# 2115452          11  3.182006  0.0      34       60
# 2115453          17  3.721612  0.0      58      101
# 2115454           8  3.121928  0.0      25       41
# 2115455           8  2.250000  0.0      10       15
# 2115456           4  3.000000  0.0      21       30
# 2115457          10  3.182006  0.0      34       59
# 2115458          13  3.640224  0.0      46       78
# 2115459           5  3.095795  0.0      27       43
# 2115460           6  3.000000  0.0      21       30
# 2115461          13  3.292770  0.0      39       71
# 2115462           8  2.750000  0.0      17       25
# 2115463           7  3.000000  0.0      21       30
# 2115464           4  2.750000  0.0      17       25
# 2115465           4  3.000000  0.0      21       30
# 2115466          16  3.576618  0.0      52       94
# 2115467          13  3.521641  0.0      42       69
# 2115468          10  3.452820  0.0      45       79
# 2115469           4  3.277613  0.0      30       47
# 2115470          14  3.337175  0.0      41       73
# 2115471          12  3.852169  0.0      58       98
# 2115472          13  3.238901  0.0      34       56
# 2115473           8  3.378783  0.0      38       65
#
# [2115474 rows x 10 columns]

# %%
data = data.drop('domain', axis = 1)
data = data.drop('main_domain', axis = 1)

# %%
X = data.drop('label', axis=1)
Y = data['label']

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
Xmin_max = min_max_scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
x,y = data.ix[:,1:],data.ix[:,0]
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(x, y, train_size = 0.8, test_size=0.2, random_state=0, stratify = y)
X_train, X_test, Y_train, Y_test = train_test_split(Xmin_max, Y, train_size = 0.8, test_size=0.2, random_state=0, stratify = Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ## 决策树

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(criterion='entropy')
decision_tree.fit(X_train1, Y_train1)
acc_decision_tree = round(decision_tree.score(X_train1, Y_train1) * 100, 2)
print("Training accuracy：", acc_decision_tree)
# Out:
# Training accuracy： 92.76

# %%
from sklearn.metrics import accuracy_score, recall_score
Y_pred = decision_tree.predict(X_test1)
print("Test accuary：", accuracy_score(Y_test1, Y_pred))
print("Recall score:", recall_score(Y_test1, Y_pred))
# Out:
# Test accuary： 0.9148607286779565
# Recall score: 0.916929360721307

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score
strKFold = StratifiedKFold(n_splits=10,shuffle=True,random_state=0)
scores = cross_val_score(decision_tree,X,Y,cv=strKFold)
print("Mean score of straitified cross validation:{:.2f}".format(scores.mean()))
# Out:
# Mean score of straitified cross validation:0.91

# %% [markdown]
# ## Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='liblinear', max_iter = 10000)
log_reg.fit(X_train, Y_train)
acc_log = round(log_reg.score(X_train, Y_train) * 100, 2)
print("Training accuracy：", acc_log)
# Out:
# Training accuracy： 84.06

# %%
from sklearn.metrics import accuracy_score, recall_score
Y_pred = log_reg.predict(X_test)
print("Test accuracy：", accuracy_score(Y_test, Y_pred))
print("Recall score:", recall_score(Y_test, Y_pred))
# Out:
# Test accuracy： 0.8419669341400867
# Recall score: 0.8556411429733577

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score
strKFold = StratifiedKFold(n_splits=10,shuffle=True,random_state=0)
scores = cross_val_score(log_reg,X,Y,cv=strKFold)
print("Mean score of straitified cross validation:{:.2f}".format(scores.mean()))
# Out:
# Mean score of straitified cross validation:0.84

# %%
def get_features(domain):
    main_domain = get_main_domain(domain)
    length = len(main_domain)
    vowel = get_vowel(main_domain)
    consonants = get_consonants(main_domain)
    shannon = get_shannon(main_domain)
    num = get_num(main_domain)
    bigram = get_bigram(main_domain)
    trigram = get_trigram(main_domain)
    return [length, vowel, consonants, shannon, num, bigram, trigram]

# %%
def test_domain(domain):
    test_features = []
    test_features.append(get_features(domain))
    pre = decision_tree.predict(test_features)
    print("DGA") if pre == 1 else print("Normal")

# %%
domain = 'jianshu.com'
test_domain(domain)
# Out:
# Normal

# %%
domain = 'promotion.aliyun.com'
test_domain(domain)
# Out:
# Normal

# %%
domain = 'kajugcffktsgskchaymsj.infosec'
test_domain(domain)
# Out:
# DGA
